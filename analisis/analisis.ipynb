# %%
import pandas as pd
from pathlib import Path
import sys
sys.path.append("..")
from src.data import recoger_data

# %%
DATA_PATH = Path("../data")
RAW_PATH = DATA_PATH / "raw"
PROCESSED_PATH = DATA_PATH / "processed"


url = "https://www.zaragoza.es/sede/servicio/urbanismo-infraestructuras/estacion-bicicleta.json?rows=300"

datos = recoger_data(url)

# %%
df = pd.json_normalize(datos["result"])
pd.set_option('display.max_colwidth', None)
df.to_csv(RAW_PATH / "datos_crudos.csv")

# %%
df.head(5)
# Out:
#     id  \
# 0  279
# 1  278
# 2  277
# 3  276
# 4  275
#
#                                                                           about  \
# 0  http://www.zaragoza.es/ciudad/viapublica/movilidad/bici/detalle_Bizi?oid=279
# 1  http://www.zaragoza.es/ciudad/viapublica/movilidad/bici/detalle_Bizi?oid=278
# 2  http://www.zaragoza.es/ciudad/viapublica/movilidad/bici/detalle_Bizi?oid=277
# 3  http://www.zaragoza.es/ciudad/viapublica/movilidad/bici/detalle_Bizi?oid=276
# 4  http://www.zaragoza.es/ciudad/viapublica/movilidad/bici/detalle_Bizi?oid=275
#
#                            title      estado  \
# 0            193- Pza. La Ermita  IN_SERVICE
# 1        270- Delicias Autobuses  IN_SERVICE
# 2  150- Mrio. Siresa: Dr. Iranzo  IN_SERVICE
# 3            127- Navarra: Rioja  IN_SERVICE
# 4    20- Camón Aznar: C. Augusto  IN_SERVICE
#
#                                                                                                 estadoEstacion  \
# 0  http://vocab.linkeddata.es/datosabiertos/kos/transporte/bicicleta-publica/tipo-estado-estacion/no-operativa
# 1  http://vocab.linkeddata.es/datosabiertos/kos/transporte/bicicleta-publica/tipo-estado-estacion/no-operativa
# 2  http://vocab.linkeddata.es/datosabiertos/kos/transporte/bicicleta-publica/tipo-estado-estacion/no-operativa
# 3  http://vocab.linkeddata.es/datosabiertos/kos/transporte/bicicleta-publica/tipo-estado-estacion/no-operativa
# 4  http://vocab.linkeddata.es/datosabiertos/kos/transporte/bicicleta-publica/tipo-estado-estacion/no-operativa
#
#                          address  \
# 0            193- Pza. La Ermita
# 1        270- Delicias Autobuses
# 2  150- Mrio. Siresa: Dr. Iranzo
# 3            127- Navarra: Rioja
# 4    20- Camón Aznar: C. Augusto
#
#                                                                                                                 tipoEquipamiento  \
# 0  http://vocab.linkeddata.es/datosabiertos/kos/urbanismo-infraestructuras/equipamiento/tipo-equipamiento/estacion-de-bicicletas
# 1  http://vocab.linkeddata.es/datosabiertos/kos/urbanismo-infraestructuras/equipamiento/tipo-equipamiento/estacion-de-bicicletas
# 2  http://vocab.linkeddata.es/datosabiertos/kos/urbanismo-infraestructuras/equipamiento/tipo-equipamiento/estacion-de-bicicletas
# 3  http://vocab.linkeddata.es/datosabiertos/kos/urbanismo-infraestructuras/equipamiento/tipo-equipamiento/estacion-de-bicicletas
# 4  http://vocab.linkeddata.es/datosabiertos/kos/urbanismo-infraestructuras/equipamiento/tipo-equipamiento/estacion-de-bicicletas
#
#    bicisDisponibles  anclajesDisponibles          lastUpdated  \
# 0                 3                   16  2026-07-22T11:53:09
# 1                18                    1  2026-07-22T11:53:09
# 2                 2                   16  2026-07-22T11:53:09
# 3                 1                   18  2026-07-22T11:53:09
# 4                19                    0  2026-07-22T11:53:09
#
#                                                                                                                   description  \
# 0  <ul><li>Estado: Operativa</li><li>Bicis disponibles: 3</li><li>Anclajes disponibles: 16</li></ul><p>Actualizado: 11:53</p>
# 1  <ul><li>Estado: Operativa</li><li>Bicis disponibles: 18</li><li>Anclajes disponibles: 1</li></ul><p>Actualizado: 11:53</p>
# 2  <ul><li>Estado: Operativa</li><li>Bicis disponibles: 2</li><li>Anclajes disponibles: 16</li></ul><p>Actualizado: 11:53</p>
# 3  <ul><li>Estado: Operativa</li><li>Bicis disponibles: 1</li><li>Anclajes disponibles: 18</li></ul><p>Actualizado: 11:53</p>
# 4  <ul><li>Estado: Operativa</li><li>Bicis disponibles: 19</li><li>Anclajes disponibles: 0</li></ul><p>Actualizado: 11:53</p>
#
#                                                descripcion  \
# 0            Datos de la estación bizi 193- Pza. La Ermita
# 1        Datos de la estación bizi 270- Delicias Autobuses
# 2  Datos de la estación bizi 150- Mrio. Siresa: Dr. Iranzo
# 3            Datos de la estación bizi 127- Navarra: Rioja
# 4    Datos de la estación bizi 20- Camón Aznar: C. Augusto
#
#                                                     icon geometry.type  \
# 0  //www.zaragoza.es/contenidos/iconos/bizi/conbicis.png         Point
# 1  //www.zaragoza.es/contenidos/iconos/bizi/conbicis.png         Point
# 2  //www.zaragoza.es/contenidos/iconos/bizi/conbicis.png         Point
# 3  //www.zaragoza.es/contenidos/iconos/bizi/conbicis.png         Point
# 4  //www.zaragoza.es/contenidos/iconos/bizi/conbicis.png         Point
#
#                        geometry.coordinates
# 0   [-0.911215893796391, 41.63149540266168]
# 1  [-0.9107841716732368, 41.65951733457972]
# 2  [-0.8640994330671391, 41.64758556666017]
# 3  [-0.908685551690069, 41.655535911165344]
# 4  [-0.8853921642559097, 41.65246416373115]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    276 non-null    str
#  1   about                 276 non-null    str
#  2   title                 276 non-null    str
#  3   estado                276 non-null    str
#  4   estadoEstacion        276 non-null    str
#  5   address               276 non-null    str
#  6   tipoEquipamiento      276 non-null    str
#  7   bicisDisponibles      276 non-null    int64
#  8   anclajesDisponibles   276 non-null    int64
#  9   lastUpdated           276 non-null    str
#  10  description           276 non-null    str
#  11  descripcion           276 non-null    str
#  12  icon                  276 non-null    str
#  13  geometry.type         276 non-null    str
#  14  geometry.coordinates  276 non-null    object
# dtypes: int64(2), object(1), str(12)
# memory usage: 32.5+ KB

# %%
df.describe()
# Out:
#        bicisDisponibles  anclajesDisponibles
# count        276.000000           276.000000
# mean           6.007246            13.380435
# std            6.435127             5.765431
# min            0.000000             0.000000
# 25%            1.000000             9.000000
# 50%            3.000000            15.000000
# 75%           10.000000            18.000000
# max           27.000000            30.000000

# %%
df.columns
# Out:
# Index(['id', 'about', 'title', 'estado', 'estadoEstacion', 'address',
#        'tipoEquipamiento', 'bicisDisponibles', 'anclajesDisponibles',
#        'lastUpdated', 'description', 'descripcion', 'icon', 'geometry.type',
#        'geometry.coordinates'],
#       dtype='str')

# %% [markdown]
# # Normalización de dataframe

# %% [markdown]
# Elimino columnas que no sirven para el analisis.

# %%
columnas_eliminar = ["about","estadoEstacion","tipoEquipamiento","icon","title","description","descripcion","geometry.type"]

df = df.drop(columns=columnas_eliminar)

# %%
df.head(5)
# Out:
#     id      estado                        address  bicisDisponibles  \
# 0  279  IN_SERVICE            193- Pza. La Ermita                 3
# 1  278  IN_SERVICE        270- Delicias Autobuses                18
# 2  277  IN_SERVICE  150- Mrio. Siresa: Dr. Iranzo                 2
# 3  276  IN_SERVICE            127- Navarra: Rioja                 1
# 4  275  IN_SERVICE    20- Camón Aznar: C. Augusto                19
#
#    anclajesDisponibles          lastUpdated  \
# 0                   16  2026-07-22T11:53:09
# 1                    1  2026-07-22T11:53:09
# 2                   16  2026-07-22T11:53:09
# 3                   18  2026-07-22T11:53:09
# 4                    0  2026-07-22T11:53:09
#
#                        geometry.coordinates
# 0   [-0.911215893796391, 41.63149540266168]
# 1  [-0.9107841716732368, 41.65951733457972]
# 2  [-0.8640994330671391, 41.64758556666017]
# 3  [-0.908685551690069, 41.655535911165344]
# 4  [-0.8853921642559097, 41.65246416373115]

# %% [markdown]
# El motivo de las columnas que eliminamos es que son datos que no nos sirven para analizar (fotos) y luego title y address es el mismo dato y ocua espacio innecesario.

# %% [markdown]
# Normalizamos nombres de columnas

# %%
mapeo = {
    "bicisDisponibles" :"bicis_disponibles",
    "anclajesDisponibles" : "anclajes_disponibles",
    "lastUpdated" : "last_updated"
}

df = df.rename(columns=mapeo)

# %% [markdown]
# ### Fecha y Hora

# %%
df["last_updated"] = pd.to_datetime(df["last_updated"])

# %%
df["fecha"] = df["last_updated"].dt.date
df["mes"] = df["last_updated"].dt.month
df["dia"] = df["last_updated"].dt.day
df["dia_semana"] = df["last_updated"].dt.day_name(locale='es_ES')
df["hora"] = df["last_updated"].dt.hour
df["minutos"] = df["last_updated"].dt.minute

# %%
df.head(5)
# Out:
#     id      estado                        address  bicis_disponibles  \
# 0  279  IN_SERVICE            193- Pza. La Ermita                  3
# 1  278  IN_SERVICE        270- Delicias Autobuses                 18
# 2  277  IN_SERVICE  150- Mrio. Siresa: Dr. Iranzo                  2
# 3  276  IN_SERVICE            127- Navarra: Rioja                  1
# 4  275  IN_SERVICE    20- Camón Aznar: C. Augusto                 19
#
#    anclajes_disponibles        last_updated  \
# 0                    16 2026-07-22 11:53:09
# 1                     1 2026-07-22 11:53:09
# 2                    16 2026-07-22 11:53:09
# 3                    18 2026-07-22 11:53:09
# 4                     0 2026-07-22 11:53:09
#
#                        geometry.coordinates       fecha  mes  dia dia_semana  \
# 0   [-0.911215893796391, 41.63149540266168]  2026-07-22    7   22  Miércoles
# 1  [-0.9107841716732368, 41.65951733457972]  2026-07-22    7   22  Miércoles
# 2  [-0.8640994330671391, 41.64758556666017]  2026-07-22    7   22  Miércoles
# 3  [-0.908685551690069, 41.655535911165344]  2026-07-22    7   22  Miércoles
# 4  [-0.8853921642559097, 41.65246416373115]  2026-07-22    7   22  Miércoles
#
#    hora  minutos
# 0    11       53
# 1    11       53
# 2    11       53
# 3    11       53
# 4    11       53

# %% [markdown]
# ### Longitud y Latitud

# %%
print(type(df["geometry.coordinates"].iloc[0]))
# Out:
# <class 'list'>

# %%
df['longitud'] = df['geometry.coordinates'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)
df['latitud'] = df['geometry.coordinates'].apply(lambda x: x[1] if isinstance(x, list) and len(x) > 0 else x)

# %%
df.head(5)
# Out:
#     id      estado                        address  bicis_disponibles  \
# 0  279  IN_SERVICE            193- Pza. La Ermita                  3
# 1  278  IN_SERVICE        270- Delicias Autobuses                 18
# 2  277  IN_SERVICE  150- Mrio. Siresa: Dr. Iranzo                  2
# 3  276  IN_SERVICE            127- Navarra: Rioja                  1
# 4  275  IN_SERVICE    20- Camón Aznar: C. Augusto                 19
#
#    anclajes_disponibles        last_updated  \
# 0                    16 2026-07-22 11:53:09
# 1                     1 2026-07-22 11:53:09
# 2                    16 2026-07-22 11:53:09
# 3                    18 2026-07-22 11:53:09
# 4                     0 2026-07-22 11:53:09
#
#                        geometry.coordinates       fecha  mes  dia dia_semana  \
# 0   [-0.911215893796391, 41.63149540266168]  2026-07-22    7   22  Miércoles
# 1  [-0.9107841716732368, 41.65951733457972]  2026-07-22    7   22  Miércoles
# 2  [-0.8640994330671391, 41.64758556666017]  2026-07-22    7   22  Miércoles
# 3  [-0.908685551690069, 41.655535911165344]  2026-07-22    7   22  Miércoles
# 4  [-0.8853921642559097, 41.65246416373115]  2026-07-22    7   22  Miércoles
#
#    hora  minutos  longitud    latitud
# 0    11       53 -0.911216  41.631495
# 1    11       53 -0.910784  41.659517
# 2    11       53 -0.864099  41.647586
# 3    11       53 -0.908686  41.655536
# 4    11       53 -0.885392  41.652464

# %% [markdown]
# Eliminamos la columna de geometry, ya que no hace mas falta.

# %%
df = df.drop(columns="geometry.coordinates")

# %%
df.head(5)
# Out:
#     id      estado                        address  bicis_disponibles  \
# 0  279  IN_SERVICE            193- Pza. La Ermita                  3
# 1  278  IN_SERVICE        270- Delicias Autobuses                 18
# 2  277  IN_SERVICE  150- Mrio. Siresa: Dr. Iranzo                  2
# 3  276  IN_SERVICE            127- Navarra: Rioja                  1
# 4  275  IN_SERVICE    20- Camón Aznar: C. Augusto                 19
#
#    anclajes_disponibles        last_updated       fecha  mes  dia dia_semana  \
# 0                    16 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 1                     1 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 2                    16 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 3                    18 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 4                     0 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
#
#    hora  minutos  longitud    latitud
# 0    11       53 -0.911216  41.631495
# 1    11       53 -0.910784  41.659517
# 2    11       53 -0.864099  41.647586
# 3    11       53 -0.908686  41.655536
# 4    11       53 -0.885392  41.652464

# %% [markdown]
# ### Separar número de estación

# %%
df["estacion"] = df["address"].str.split('-').str[0]

# %%
df.head(5)
# Out:
#     id      estado                        address  bicis_disponibles  \
# 0  279  IN_SERVICE            193- Pza. La Ermita                  3
# 1  278  IN_SERVICE        270- Delicias Autobuses                 18
# 2  277  IN_SERVICE  150- Mrio. Siresa: Dr. Iranzo                  2
# 3  276  IN_SERVICE            127- Navarra: Rioja                  1
# 4  275  IN_SERVICE    20- Camón Aznar: C. Augusto                 19
#
#    anclajes_disponibles        last_updated       fecha  mes  dia dia_semana  \
# 0                    16 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 1                     1 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 2                    16 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 3                    18 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 4                     0 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
#
#    hora  minutos  longitud    latitud estacion
# 0    11       53 -0.911216  41.631495      193
# 1    11       53 -0.910784  41.659517      270
# 2    11       53 -0.864099  41.647586      150
# 3    11       53 -0.908686  41.655536      127
# 4    11       53 -0.885392  41.652464       20

# %%
df["nombre_estacion"] = df["address"].str.split('-').str[1]

# %%
df.head(5)
# Out:
#     id      estado                        address  bicis_disponibles  \
# 0  279  IN_SERVICE            193- Pza. La Ermita                  3
# 1  278  IN_SERVICE        270- Delicias Autobuses                 18
# 2  277  IN_SERVICE  150- Mrio. Siresa: Dr. Iranzo                  2
# 3  276  IN_SERVICE            127- Navarra: Rioja                  1
# 4  275  IN_SERVICE    20- Camón Aznar: C. Augusto                 19
#
#    anclajes_disponibles        last_updated       fecha  mes  dia dia_semana  \
# 0                    16 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 1                     1 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 2                    16 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 3                    18 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
# 4                     0 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles
#
#    hora  minutos  longitud    latitud estacion            nombre_estacion
# 0    11       53 -0.911216  41.631495      193             Pza. La Ermita
# 1    11       53 -0.910784  41.659517      270         Delicias Autobuses
# 2    11       53 -0.864099  41.647586      150   Mrio. Siresa: Dr. Iranzo
# 3    11       53 -0.908686  41.655536      127             Navarra: Rioja
# 4    11       53 -0.885392  41.652464       20    Camón Aznar: C. Augusto

# %% [markdown]
# Elimino la columna address ya que separe los datos en 2 columnas.

# %%
df = df.drop(columns="address")

# %%
df.head(5)
# Out:
#     id      estado  bicis_disponibles  anclajes_disponibles  \
# 0  279  IN_SERVICE                  3                    16
# 1  278  IN_SERVICE                 18                     1
# 2  277  IN_SERVICE                  2                    16
# 3  276  IN_SERVICE                  1                    18
# 4  275  IN_SERVICE                 19                     0
#
#          last_updated       fecha  mes  dia dia_semana  hora  minutos  \
# 0 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles    11       53
# 1 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles    11       53
# 2 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles    11       53
# 3 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles    11       53
# 4 2026-07-22 11:53:09  2026-07-22    7   22  Miércoles    11       53
#
#    longitud    latitud estacion            nombre_estacion
# 0 -0.911216  41.631495      193             Pza. La Ermita
# 1 -0.910784  41.659517      270         Delicias Autobuses
# 2 -0.864099  41.647586      150   Mrio. Siresa: Dr. Iranzo
# 3 -0.908686  41.655536      127             Navarra: Rioja
# 4 -0.885392  41.652464       20    Camón Aznar: C. Augusto

# %%
df.to_csv(PROCESSED_PATH / "datos_limpios.csv")

# %%
from src.cargar_sqlite import cargar_a_sqlite

cargar_a_sqlite(PROCESSED_PATH / "datos_limpios.csv")
